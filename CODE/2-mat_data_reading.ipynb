# %%
import scipy.io as sio
import wfdb

# %%
mat_data = sio.loadmat(r"E:\PROJECTS\CARDIAC-PROJECT-UPDATED\DATASET\MATLAB DATA\a0001.mat")
print(mat_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'ecg', 'pcg', 'fs', 'channels'])

# %%
ecg_record = wfdb.rdrecord(r"E:\PROJECTS\CARDIAC-PROJECT-UPDATED\DATASET\PHYSIONET RAW DATA\training-a\a0001")
print(ecg_record.units)
# Out:
# ['mV', 'mV']

# %%
ecg = mat_data['ecg']
pcg = mat_data['pcg']

fs = mat_data['fs'][0][0]

channels = mat_data['channels']

# %%
ecg.shape
# Out:
# (1, 71332)

# %%
pcg.shape
# Out:
# (1, 71332)

# %%
channels
# Out:
# array(['PCG', 'ECG'], dtype='<U3')

# %%
fs
# Out:
# np.int64(2000)
